# %% [markdown]
# # Build a custom NER using TESTEset.json data. The data are avalable in the google drive.

# %%
import json
import spacy
from tqdm import tqdm
from spacy.tokens import DocBin
from spacy.util import filter_spans

# %%
with open('/content/TASTEset.json', 'r') as f:
    data = json.load(f)

# %%
data[0]
# Out:
# ['5 ounces rum\n4 ounces triple sec\n3 ounces Tia Maria\n20 ounces orange juice\n',
#  {'entities': [[0, 1, 'QUANTITY'],
#    [2, 8, 'UNIT'],
#    [9, 12, 'FOOD'],
#    [13, 14, 'QUANTITY'],
#    [15, 21, 'UNIT'],
#    [22, 32, 'FOOD'],
#    [33, 34, 'QUANTITY'],
#    [35, 41, 'UNIT'],
#    [42, 51, 'FOOD'],
#    [52, 54, 'QUANTITY'],
#    [55, 61, 'UNIT'],
#    [62, 74, 'FOOD']]}]

# %%
nlp  = spacy.blank('en')
doc_bin = DocBin()

# %%
for training in tqdm(data):
    # print(training)
    text = training[0]
    # print(f'TEXTE: {text}')
    labels = training[1]['entities']
    # print(f'LABELS: {labels}')
    # print('*' * 50)

    # Create a Doc object from the text without running the full pipeline
    doc = nlp.make_doc(text)

    # Initialize an empty list to store entity spans
    ents = []

    # Iterate over the entities in the training example
    for start, end, label in labels:
        # Create a span for each entity
        span = doc.char_span(start, end, label=label, alignment_mode="contract")

        # If the span is valid, add it to the list of entities
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)

    # Filter overlapping spans to ensure each token is part of at most one entity
    filtered_ents = filter_spans(ents)

    # Assign the filtered entities to the document
    doc.ents = filtered_ents

    # Add the processed document to the DocBin
    doc_bin.add(doc)

# Save the DocBin with the processed documents to disk
doc_bin.to_disk("customNER.spacy")
# Out:
# 100%|██████████| 700/700 [00:00<00:00, 1505.36it/s]

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./customNER.spacy --paths.dev ./customNER.spacy
# Out:
# ℹ Saving to output directory: .
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     61.87   19.04   15.13   25.65    0.19
#   0     200        289.12   4656.80   90.25   90.74   89.76    0.90
#   1     400        336.98   2266.59   94.11   94.61   93.61    0.94
#   2     600        496.90   1995.32   96.04   95.80   96.29    0.96
#   3     800        467.18   1865.83   97.35   97.42   97.28    0.97
#   5    1000        523.26   1692.77   98.09   98.06   98.11    0.98
#   7    1200        642.34   1601.69   98.87   98.91   98.83    0.99
#  10    1400        661.42   1392.95   99.18   99.18   99.17    0.99
#  13    1600        769.89   1321.08   99.52   99.48   99.55    1.00
#  17    1800        876.47   1217.37   99.63   99.60   99.66    1.00
#  22    2000        954.82   1232.36   99.66   99.65   99.66    1.00
#  28    2200        947.35   1142.07   99.76   99.76   99.77    1.00
#  35    2400        929.59   1047.78   99.78   99.81   99.75    1.00
#  43    2600       1052.91    930.34   99.81   99.85   99.78    1.00
#  50    2800        868.10    812.12   99.86   99.87   99.86    1.00
#  57    3000        764.05    705.52   99.91   99.91   99.90    1.00
#  65    3200        805.12    608.30   99.89   99.87   99.91    1.00
#  72    3400        895.74    619.99   99.90   99.89   99.90    1.00
#  80    3600        888.83    604.71   99.91   99.93   99.90    1.00
#  87    3800        924.43    598.09   99.88   99.89   99.87    1.00
#  94    4000        842.08    460.97   99.93   99.93   99.93    1.00
# 102    4200        870.16    437.59   99.91   99.90   99.91    1.00
# 109    4400       1020.93    508.40   99.92   99.93   99.92    1.00
# 117    4600       1035.67    467.89   99.93   99.94   99.92    1.00
# 124    4800        901.41    390.43   99.91   99.92   99.90    1.00
# 131    5000        889.68    384.38   99.94   99.93   99.95    1.00
# 139    5200       1008.24    425.74   99.93   99.93   99.93    1.00
# 146    5400        611.77    279.18   99.95   99.95   99.96    1.00
# 154    5600        871.35    326.06   99.95   99.96   99.94    1.00
# 161    5800        852.92    316.64   99.94   99.94   99.95    1.00
# 168    6000        951.69    313.53   99.96   99.97   99.95    1.00
# 176    6200       1055.45    301.26   99.95   99.96   99.95    1.00
# 183    6400       1573.00    343.52   99.96   99.96   99.96    1.00
# 191    6600        969.69    268.46   99.97   99.97   99.96    1.00
# 198    6800       1273.65    311.24   99.94   99.94   99.93    1.00
# 205    7000       1310.25    299.44   99.95   99.96   99.94    1.00
# 213    7200        835.11    211.60   99.97   99.97   99.96    1.00
# 220    7400       1131.07    200.99   99.97   99.98   99.96    1.00
# 228    7600       1337.71    248.04   99.97   99.97   99.96    1.00
# 235    7800       1148.27    237.38   99.97   99.97   99.96    1.00
# 242    8000       1222.32    249.57   99.96   99.95   99.96    1.00
# 250    8200       1249.48    206.90   99.96   99.96   99.96    1.00
# ✔ Saved pipeline to output directory
# model-last

# %%
model_ner = spacy.load("model-best")

# %%
# Intitalize the colours for the NER

colors = {"UNIT": "#F67DE3", "FOOD": "#7DF6D9", "QUANTITY":"#a6e22d", "COLOR": "#e6db74", "PART": "#f92672", "PHYSICAL_QUALITY": "#fd971f", "PROCESS": "#ae81ff", "TASTE": "#f92672"}
options = {"colors": colors}

# %%
import pandas as pd

df = pd.read_excel('/content/cooking.xlsx')
df = df.iloc[1: 5, 1:]
df.rename(columns= {"Unnamed: 1": "Tiltle", "Unnamed: 2": "Instructions"}, inplace=True)

# %%
for index, row in df.iterrows():

    text = row["Instructions"]
    doc = model_ner(text)
    spacy.displacy.render(doc,style="ent",options=options, jupyter=True)
    print('\n')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Pat chicken dry with paper towels, season all over with 2 tsp. salt, and tie legs together with kitchen twine. Let sit
# <mark class="entity" style="background: #fd971f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at room temperature 1 hour.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PHYSICAL_QUALITY</span>
# </mark>
# <br>Meanwhile, halve squash and scoop
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     out seeds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# . Run a vegetable peeler along ridges of squash halves
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     to remove skin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PURPOSE</span>
# </mark>
# .
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cut
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     each half into ½&quot;-thick wedges; arrange
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  on a rimmed baking sheet.<br>
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Combine sage
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , rosemary, and
# <mark class="entity" style="background: #a6e22d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tbsp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
# .
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     melted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter in a large bowl;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pour half of mixture over squash on baking sheet. Sprinkle squash with allspice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# ,
# <mark class="entity" style="background: #e6db74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     red
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COLOR</span>
# </mark>
#  pepper flakes, and ½
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tsp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
# .
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  and
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     season with
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
#
# <mark class="entity" style="background: #e6db74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COLOR</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# ; toss to coat.<br>
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Add bread
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , apples, oil, and
# <mark class="entity" style="background: #a6e22d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ¼
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tsp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
# .
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     to remaining herb butter in bowl;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PURPOSE</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     season with
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#
# <mark class="entity" style="background: #e6db74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     black
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COLOR</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Preheat oven to 400
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     °
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# F and line a rimmed baking sheet with parchment. In a large bowl, whisk the egg whites until foamy (there shouldn’t be any liquid whites in the bowl).
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Add the potatoes and toss until they’re well coated with the egg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  whites, then transfer to a strainer or colander and let the excess whites drain. Season the potatoes with the salt,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , and herbs. Scatter the potatoes on the baking sheet (make sure they’re not touching) and roast until the potatoes are very crispy and tender when poked with a knife, 15 to 20 minutes (depending on the size of the potatoes).<br>Transfer to a bowl and serve.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Place a rack in middle of oven; preheat to 400°. Bring evaporated milk and
# <mark class="entity" style="background: #fd971f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     whole
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PHYSICAL_QUALITY</span>
# </mark>
#  milk to a bare simmer in a large
# <mark class="entity" style="background: #fd971f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     saucepan over medium heat. Whisk in garlic powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PHYSICAL_QUALITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion powder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# ,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     paprika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# ,
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pepper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , and 1
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tsp
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
# . salt. Working in batches, whisk in three fourths of the cheddar, then all of the cream cheese.<br>Meanwhile, bring a large pot of generously
# <mark class="entity" style="background: #f92672; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TASTE</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  to a boil (it should have a little less salt than seawater). Cook macaroni, stirring occasionally,
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     until very al dente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# , about 4 minutes. Drain in a colander.<br>
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Add macaroni to cheese sauce in pan and mix until well coated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# . Evenly
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spread out half of macaroni mixture in a 13x9&quot; baking dish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# . Sprinkle half of
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     remaining cheddar evenly over. Layer remaining macaroni mixture on top and sprinkle with remaining cheddar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# . Bake until all of the cheese is
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     melted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# , about 10 minutes. Let
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cool slightly before serving
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Preheat oven to 350
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     °F with rack in middle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# .
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Generously
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter baking dish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# .<br>Put bread in 2 shallow baking pans and
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bake
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# , switching position of pans halfway through baking, until just dried out, about 10 minutes.<br>Heat 1
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#  oil in a 12-inch heavy skillet over
# <mark class="entity" style="background: #fd971f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     medium-high heat until it shimmers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PHYSICAL_QUALITY</span>
# </mark>
# , then cook half of sausage, stirring and breaking it into small pieces,
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     until golden brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# , about 6 minutes. Transfer with a slotted spoon to a large bowl.
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brown remaining sausage in remaining tablespoon oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , transferring to bowl.<br>Pour off fat
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     from skillet and wipe clean. Heat butter over medium heat until foam subsides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , then cook onions, celery, garlic, and
# <mark class="entity" style="background: #a6e22d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ½
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#  each of
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  and pepper, stirring occasionally,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     until golden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PURPOSE</span>
# </mark>
# , 12 to 15 minutes. Add vegetables and bread to sausage.<br>
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Whisk together eggs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# ,
# <mark class="entity" style="background: #a6e22d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ½
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# , turkey stock, cheese, and parsley, then stir into stuffing and cool completely,
# <mark class="entity" style="background: #a6e22d; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 30 minutes.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  Reserve 5
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cups
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stuffing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
#  to stuff turkey and
# <mark class="entity" style="background: #ae81ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spoon remainder into baking dish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROCESS</span>
# </mark>
# , then drizzle with remaining ¼
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNIT</span>
# </mark>
#
# <mark class="entity" style="background: #7DF6D9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cream. Cover stuffing and chill.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FOOD</span>
# </mark>
# <br>About
# <ma

# %%
df.head()
# Out:
#                                               Tiltle  \
# 1  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 2                    Crispy Salt and Pepper Potatoes
# 3                        Thanksgiving Mac and Cheese
# 4                 Italian Sausage and Bread Stuffing
#
#                                         Instructions
# 1  Pat chicken dry with paper towels, season all ...
# 2  Preheat oven to 400°F and line a rimmed baking...
# 3  Place a rack in middle of oven; preheat to 400...
# 4  Preheat oven to 350°F with rack in middle. Gen...
